# %% [markdown]
# # 线性回归算法

# %% [raw]
# 解决回归问题
# 思想简单，实现容易
# 许多强大非线性模型基础
# 结果具有很好的可解释性
# 蕴含机器学习中很多重要思想

# %% [raw]
# 寻找一条直线，最大程度的拟合样本特征和样本输出标记之间的关系
# 样本特征只有一个：简单线性回归
# y = ax + b

# %% [markdown]
# 一类机器学习算法的基本思路

# %% [raw]
# 通过分析问题，确定问题的损失函数或效用函数；
# 通过最优化损失函数或效用函数，获得机器学习模型
# 近乎所有参数学习的算法都是这样的套路：
# 线性回归 多项式回归 逻辑回归 SVM 神经网络

# %%
# 引入图片
from IPython.display import Image
Image(filename=r"image/x1.png") # 有转义字符 \ 在路径前加上r

# %%
from IPython.display import Image
Image(filename=r"image/x2.png")

# %%
from IPython.display import Image
Image(filename=r"image/x3.png")

# %%
from IPython.display import Image
Image(filename=r"image/x4.png")

# %%
from IPython.display import Image
Image(filename=r"image/x5.png")
