# %% [markdown]
# # 梯度下降法

# %% [markdown]
# 梯度下降法不是一个机器学习算法，而是一种基于搜索的最优化方法
# 作用：最小化一个损失函数
# 梯度上升法：最大化一个效用函数

# %%
from IPython.display import Image
Image(filename=r"image/x1.png")

# %%
from IPython.display import Image
Image(filename=r"image/x2.png")

# %% [markdown]
# # 梯度下降法模拟

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 画曲线 140个点 使曲线平滑
plot_x = np.linspace(-1, 6, 141)

# %%
plot_x
# Out:
# array([-1.  , -0.95, -0.9 , -0.85, -0.8 , -0.75, -0.7 , -0.65, -0.6 ,
#        -0.55, -0.5 , -0.45, -0.4 , -0.35, -0.3 , -0.25, -0.2 , -0.15,
#        -0.1 , -0.05,  0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,
#         0.35,  0.4 ,  0.45,  0.5 ,  0.55,  0.6 ,  0.65,  0.7 ,  0.75,
#         0.8 ,  0.85,  0.9 ,  0.95,  1.  ,  1.05,  1.1 ,  1.15,  1.2 ,
#         1.25,  1.3 ,  1.35,  1.4 ,  1.45,  1.5 ,  1.55,  1.6 ,  1.65,
#         1.7 ,  1.75,  1.8 ,  1.85,  1.9 ,  1.95,  2.  ,  2.05,  2.1 ,
#         2.15,  2.2 ,  2.25,  2.3 ,  2.35,  2.4 ,  2.45,  2.5 ,  2.55,
#         2.6 ,  2.65,  2.7 ,  2.75,  2.8 ,  2.85,  2.9 ,  2.95,  3.  ,
#         3.05,  3.1 ,  3.15,  3.2 ,  3.25,  3.3 ,  3.35,  3.4 ,  3.45,
#         3.5 ,  3.55,  3.6 ,  3.65,  3.7 ,  3.75,  3.8 ,  3.85,  3.9 ,
#         3.95,  4.  ,  4.05,  4.1 ,  4.15,  4.2 ,  4.25,  4.3 ,  4.35,
#         4.4 ,  4.45,  4.5 ,  4.55,  4.6 ,  4.65,  4.7 ,  4.75,  4.8 ,
# ...

# %%
plot_y = (plot_x -2.5)**2 - 1

# %%
plt.plot(plot_x, plot_y)

# %%
# 求导
def dJ(theta):
    return 2*(theta-2.5)

# %%
# 损失函数
def J(theta):
    return (theta-2.5)**2-1

# %%
eta = 0.1 # 学习率
epsilon = 1e-8 # 度量0

theta = 0.0
while True:
    gradient = dJ(theta)
    last_theta = theta # 前一个theta
    theta = theta - eta * gradient  # 当前theta
    
    # 两次损失函数的差值几乎为0时退出循环
    if(abs(J(theta) - J(last_theta)) < epsilon):
        break
        
print(theta)
print(J(theta))
# Out:
# 2.499891109642585
# -0.99999998814289

# %%
theta = 0.0
theta_history = [theta]
while True:
    gradient = dJ(theta) # 梯度
    last_theta = theta # 前一个theta
    theta = theta - eta * gradient  # 当前theta
    theta_history.append(theta)
    
    # 两次损失函数的差值几乎为0时退出循环
    if(abs(J(theta) - J(last_theta)) < epsilon):
        break
        
plt.plot(plot_x, J(plot_x))
plt.plot(np.array(theta_history), J(np.array(theta_history)), color="r", marker="+")

# %%
len(theta_history)
# Out:
# 46

# %%
# 梯度下降
def gradient_descent(initial_theta, eta, epsilon=1e-8):
    theta = initial_theta
    theta_history.append(initial_theta)
    while True:
        gradient = dJ(theta)
        last_theta = theta
        theta = theta - eta * gradient
        theta_history.append(theta)

        # 两次损失函数的差值几乎为0时退出循环
        if(abs(J(theta) - J(last_theta)) < epsilon):
            break

def plot_theta_history():            
    plt.plot(plot_x, J(plot_x))
    plt.plot(np.array(theta_history), J(np.array(theta_history)), color="r", marker="+")

# %%
eta = 0.01 # 学习率
theta_history = []
gradient_descent(0, eta)
plot_theta_history()

# %%
len(theta_history)
# Out:
# 424

# %%
eta = 0.8
theta_history = []
gradient_descent(0, eta)
plot_theta_history()

# %% [markdown]
# eta太大，会报错，因此可以对损失函数做下面修改

# %% [raw]
# def J(theta):
#     try:
#         return (theta-2.5)**2-1.
#     except:
#         return (float('inf'))

# %% [raw]
# 此时会进入死循环，因为if永远都会是true,无穷-无穷不会小于0
# if(abs(J(theta) - J(last_theta)) < epsilon):
#             break

# %% [markdown]
# 对梯度下降函数作如下修改：

# %%
def gradient_descent(initial_theta, eta, n_iters=1e4, epsilion=1e-8):
    theta = initial_theta
    theta_history.append(initial_theta)
    i_iter = 0
    
    # 最多循环1e4次
    while i_iter < n_iters:
        gradient = dJ(theta)
        last_theta = theta
        theta = theta - eta * gradient
        theta_history.append(theta)

        # 两次损失函数的差值几乎为0时退出循环
        if(abs(J(theta) - J(last_theta)) < epsilon):
            break
            
        i_iter += 1

# %%
eta = 1
theta_history = []
gradient_descent(0, eta)

# %%
theta
# Out:
# 2.499891109642585

# %%
J(theta)
# Out:
# -0.99999998814289
